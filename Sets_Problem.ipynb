# %% [markdown]
# <a href="https://colab.research.google.com/github/puneet010/Summer-School-2025/blob/main/Sets_Problem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s = [-12, -3, -6, 7, 2, -2, 6, 3, 9, -7, -5, -8, 1, 11, -9, -4]
results = []

def find_zero_sum(current_list, start_index):
    # If current list has 3–6 elements, and sums to 0, save a copy
    if 3 <= len(current_list) <= 6 and sum(current_list) == 0:
        results.append(current_list[:])  # append a copy

    # Stop if already 6 elements
    if len(current_list) == 6:
        return

    # Try adding next elements one by one
    for i in range(start_index, len(s)):
        current_list.append(s[i])
        find_zero_sum(current_list, i + 1)  # move to next index (no repeats)
        current_list.pop()  # backtrack

# Start with empty list from index 0
find_zero_sum([], 0)

# Print results
for r in results:
    print(r)

print(f"\nTotal such lists found: {len(results)}")
# Out:
# [-12, -3, -6, 7, 3, 11]
# [-12, -3, -6, 9, 1, 11]
# [-12, -3, 7, 2, 6]
# [-12, -3, 7, 2, -5, 11]
# [-12, -3, 7, -2, 9, 1]
# [-12, -3, 7, 6, 9, -7]
# [-12, -3, 7, 6, 11, -9]
# [-12, -3, 7, 3, 9, -4]
# [-12, -3, 7, 1, 11, -4]
# [-12, -3, 2, -2, 6, 9]
# [-12, -3, 2, 6, 11, -4]
# [-12, -3, 2, 3, 9, 1]
# [-12, -3, 2, 9, -7, 11]
# [-12, -3, -2, 6, 11]
# [-12, -3, 6, 3, -5, 11]
# [-12, -3, 6, 9]
# [-12, -3, 3, 9, -8, 11]
# [-12, -3, 3, 1, 11]
# [-12, -3, 9, -5, 11]
# [-12, -6, 7, 2, -2, 11]
# [-12, -6, 7, 2, 6, 3]
# [-12, -6, 7, 2, 9]
# [-12, -6, 7, 6, 9, -4]
# [-12, -6, 7, 9, 11, -9]
# [-12, -6, 7, 11]
# [-12, -6, 2, 6, 9, 1]
# [-12, -6, 2, 9, 11, -4]
# [-12, -6, -2, 6, 3, 11]
# [-12, -6, -2, 9, 11]
# [-12, -6, 6, 3, 9]
# [-12, -6, 6, 9, -8, 11]
# [-12, -6, 6, 1, 11]
# [-12, -6, 3, 9, -5, 11]
# [-12, 7, 2, -2, 9, -4]
# [-12, 7, 2, 6, 1, -4]
# [-12, 7, 2, 3]
# [-12, 7, 2, 3, 9, -9]
# [-12, 7, 2, 9, -7, 1]
# [-12, 7, 2, -8, 11]
# [-12, 7, 2, 1, 11, -9]
# [-12, 7, -2, 6, 9, -8]
# ...

# %%
ProductList = {'p1':10, 'p2':15, 'p3':20, 'p4':25, 'p5':30, 'p6':35, 'p7':50,
               'p8':40, 'p9':55, 'p10':60, 'p11':65, 'p12':75, 'p13':70,
               'p14':45}
LB          = 290
UB          = 310
ResultList  = set()
